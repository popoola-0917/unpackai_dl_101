# %% [markdown]
# <a href="https://colab.research.google.com/github/popoolaademola/unpackai_dl_101/blob/main/01_CV_SolutionWorkbook_popoola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻Week 1 Workbook of unpackAI "DL101 Bootcamp"

# %% [markdown]
# ## 📕 Learning Objectives of the Week
#
# * Understand the fundamental process of building your own image classification project.

# %% [markdown]
# ## 🔗 Install & Import Required Code Packages

# %%
# !pip install -Uqq fastbook
# !pip install -Uqq unpackai
# Out:
#      |████████████████████████████████| 720 kB 5.2 MB/s
#      |████████████████████████████████| 1.2 MB 37.7 MB/s
#      |████████████████████████████████| 189 kB 47.7 MB/s
#      |████████████████████████████████| 48 kB 5.5 MB/s
#      |████████████████████████████████| 55 kB 4.6 MB/s
#      |████████████████████████████████| 558 kB 48.0 MB/s
#      |████████████████████████████████| 51 kB 347 kB/s
#      |████████████████████████████████| 130 kB 45.9 MB/s
#      |████████████████████████████████| 73 kB 2.1 MB/s
#      |████████████████████████████████| 95 kB 4.3 MB/s

# %%
from unpackai.utils import clean_error_img
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# ## unpackAI Assignment Section
#
#
# *   **Assignment 1**: Go through the multiple choice questions below and choose the correct answer. Discuss during the presentation session.
# *   **Assignment 2**: Build an entire single label classification model starting from defining your objective, gathering data to training your model and interpreting the results.

# %% [markdown]
# ## Assigment 1: Go through the multiple choice questions below and choose the correct answer. Discuss during the presentation session.

# %% [markdown]
# 1. What is overfitting?
#
# > A: Overfitting is a scenario in data science where a data model is unable to capture the relationship between the input and output variables accurately, generating a high loss on both the training set and unseen data.
#
# > B: Overfitting happens when a model learns and memorizes the detail and noise in the training data to the extent that it negatively impacts the performance of the model on new data. This results in a further decreasing loss on the training set but an increasing loss on the validation set.-
#
# > C: Overfitting is when the model is performing very well on the training, validation and test set and achieves a very low loss in all 3 data sets. This means that your model is ready to be used in practice.
#
#
# Ans: B

# %% [markdown]
# 2. What is a training, validation and test set?
#
# > A: The *training set* is the sample of data used to start fitting and training the model. The *test set* is the sample of data used to evaluate the trained models performance on new data while continuing to improve and tune the model's parameters. The *validation set* is the sample of data used to evaluate the final model without continuing to tune its parameters.
#
# > B: The *test set* is the sample of data used to start fitting and training the model. The *training set* is the sample of data used to evaluate the trained models performance on new data while continuing to improve and tune the model's parameters. The *validation set* is the sample of data used to evaluate the final model without continuing to tune its parameters.
#
# > C: The *training set* is the sample of data used to start fitting and training the model. The *validation set* is the sample of data used to evaluate the trained models performance on new data while continuing to improve and tune the model's parameters. The *test set* is the sample of data used to evaluate the final model without continuing to tune its parameters.-
#
# Ans: C

# %% [markdown]
# 3. Observe the `Learner` that you have encountered in the Coursebook. What are the key **metrics** to represent the model's performance? Name and explain them.
#
# > A: The key metrics are *epochs* and *time*. Both give us key insights how much memory the model requires and its performance.
#
# > B: The key metrics are *train_loss*, *valid_loss* and *error rate / accuray*. Each metric provides insights on the model's performance on the training set, validation set and test set.-
#
# > C: The single most important metric is the *loss*. The loss is what tells the machine and human how the model performs.
#
# Ans: B

# %% [markdown]
# 4. What is the difference between Classification and Regression in Machine Learning?
#
# > A: A *classification model* is one that attempts to predict a class, or category. That is, it's predicting from a number of discrete possibilities, such as "dog" or "cat". A *regression model* is one that attempts to predict one or more numeric quantities, such as a temperature or a location.-
#
# > B: A *regression model* is one that attempts to predict a class, or category. That is, it's predicting from a number of discrete possibilities, such as "dog" or "cat". A *classification model* is one that attempts to predict one or more numeric quantities, such as a temperature or a location.
#
# > C: A *classification model* is one that attempts to utilize sorting algorithms that can allow it to learn time-dependent patterns across multiples models different from images and speech. A *regression model* is one that attempts to to predict the "rating" or "preference" a user would give to an item.
#
# Ans: A

# %% [markdown]
# 5. What is transfer learning in Machine Learning?
#
# > A: Transfer learning is a machine learning technique where the parameters of a model are not updated through model training but simply replaced by the parameters of another pre-trained model.
#
# > B: Transfer learning is a technique where a machine learning engineer uses his expertise and techniques in another industry to a problem in an industry he does not have much experience in.
#
# > C: A: Transfer learning is a machine learning technique where a pre-trained model is re-purposed on a second related task. In practice this means that, we use an existing already-trained model and its trained "intelligence" to utilize it for our own use case.-
#
#
# Ans: B

# %% [markdown]
# ## Assignment 2: Build an entire single label classification model starting from defining your objective, gathering data to training your model and interpreting the results.

# %% [markdown]
# ### Step One - Translate a Business Goal to Machine Learning Task

# %% [markdown]
# #### 1. Define the objective (what goal, metrics to measure success)
# **Your objective:** The goal is to build a model that can identify the differnce between various birds of prey. The model should not be confused by other birds that are not in the main classes.
#
# #### 2. Describe your dataset (what data, how many classes etc.)
# **Your dataset:** My Dataset contains over 100 images in each class which are four types of raptor: Eagle, Hawk, Kestral and Owl. There is also a dataset of random bird images.
#
# **NOTE:** during the testing phase we noticed that without the 5th class "birds" the model tried to fit the image into one of the four classes, after adding the 5th class the model works better. *italicized text*
#
# #### 3. Describe your model (what is the model supposed to do)
# **Your model:** A 5-class single label classification model, which correctly classifies the type of raptor.

# %% [markdown]
# ### Step Two - Collect and construct your dataset

# %%
# !pip install -q jmd_imagescraper
from jmd_imagescraper.imagecleaner import *
from pathlib import Path
from jmd_imagescraper.core import *

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path = Path('/content/gdrive/MyDrive/unpackAI/DL101/images')
#number_images_to_download = 150

#duckduckgo_search(path, "Eagle", "photos of birds eagle", max_results=number_images_to_download)
#duckduckgo_search(path, "Owl", "photos of birds owl", max_results=number_images_to_download)
#duckduckgo_search(path, "Hawk", "photos of birds hawk", max_results=number_images_to_download)
#duckduckgo_search(path, "Kestral", "photos of birds Kestral", max_results=number_images_to_download)
#duckduckgo_search(path, "Birds", "photos of birds", max_results=number_images_to_download) #random images of birds not in the above classes

#path = Path('/content/drive/MyDrive/birdimages')
#number_images_to_download = 150
#duckduckgo_search(path, "Eagle", "photos of birds eagle", max_results=number_images_to_download)
#duckduckgo_search(path, "Owl", "photos of birds owl", max_results=number_images_to_download)
#duckduckgo_search(path, "Hawk", "photos of birds hawk", max_results=number_images_to_download)
#duckduckgo_search(path, "Kestral", "photos of birds Kestral", max_results=number_images_to_download)
#duckduckgo_search(path, "Birds", "photos of birds", max_results=number_images_to_download) #random images of birds not in the above classes

path = Path('/content/drive/MyDrive/unpack_ai/glasses_classification')
number_images_to_download = 150
duckduckgo_search(path, "face_with_glasses", "faces with glasses", max_results=number_images_to_download)
duckduckgo_search(path, "faces_without_glasses", "faces without glasses", max_results=number_images_to_download)
duckduckgo_search(path, "glasses_on_dummies", "glasses on dummies ", max_results=number_images_to_download)
duckduckgo_search(path, "dummies_and_puppet", "dummies and puppets without glasses", max_results=number_images_to_download)
duckduckgo_search(path, "glasses", "glasses without any kind of face", max_results=number_images_to_download) #random images of  not in the above classes
# Out:
# Duckduckgo search: faces with glasses
# Downloading results into /content/drive/MyDrive/unpack_ai/glasses_classification/face_with_glasses
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:18<00:00 Images downloaded]
#     </div>
# Duckduckgo search: faces without glasses
# Downloading results into /content/drive/MyDrive/unpack_ai/glasses_classification/faces_without_glasses
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:16<00:00 Images downloaded]
#     </div>
# Duckduckgo search: glasses on dummies
# Downloading results into /content/drive/MyDrive/unpack_ai/glasses_classification/glasses_on_dummies
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:16<00:00 Images downloaded]
#     </div>
# Duckduckgo search: dummies and puppets without glasses
# Downloading results into /content/drive/MyDrive/unpack_ai/glasses_classification/dummies_and_puppet
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:17<00:00 Images downloaded]
#     </div>
# Duckduckgo search: glasses without any kind of face
# Downloading results into /content/drive/MyDrive/unpack_ai/glasses_classification/glasses
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='150' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:16<00:00 Images downloaded]
#     </div>
# [Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/151_61cd25cf.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/152_2e82e904.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/153_22d8a25c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/154_cc4bf912.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/155_abd1af7f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/156_9512f28b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/157_1b53e515.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/158_7614b653.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/159_d0235213.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/160_b3da74c2.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/161_b667e909.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/162_e7b2a2c0.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/163_d2aacc25.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/164_ea87a413.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/165_550c92a4.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/166_b8d782ff.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/167_0a6af82f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/168_7b464329.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/169_ec1b09ca.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/170_9fc61970.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/171_119fa9cb.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/172_920784be.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/173_2471f16f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/174_890b3d75.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/175_5003f78f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/176_16153ccb.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/177_823b282b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/178_f7668c5b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/179_3de1e99b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/180_56eb7621.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/181_0ca218f2.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/182_cdefe237.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/183_ffb32ded.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/184_a449db26.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/185_43a9296c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/186_e2b89790.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/187_816cdf7f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/188_110c25a9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/189_9722f8a9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/190_8cb9d293.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/191_8df4aa14.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/192_487fe3e2.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/193_8971110e.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/194_273e74c4.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/195_7c892602.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/196_f2d6c4f0.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/197_305af91c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/198_a660d861.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/199_f2b224c5.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/200_8e1fa2f2.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/201_03821dce.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/202_5967293b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/203_a943c441.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/204_0de34647.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/205_32f6902e.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/206_14369cc9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/207_cf7a8390.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/208_9858c1bf.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/209_453ac32b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/210_26ba4884.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/211_31601a40.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/212_2176c85c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/213_68e8a445.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/214_df9ab4ca.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/215_ace0a3ae.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/216_31e10c46.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/217_822cf4f2.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/218_eb89422d.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/219_7fe2bf43.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/220_b3f1598b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/221_22d4b37b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/222_be7ccc98.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/223_e3ee4b45.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/224_da05fcf1.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/225_41be359b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/226_1603b52d.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/227_fedddfeb.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/228_e7b9c09b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/229_9f4d8ade.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/230_b1ec62b8.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/231_addb58a4.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/232_b2370992.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/233_b973d139.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/234_81967481.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/235_f7b01cf4.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/236_69ccf9a7.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/237_c8b6614c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/238_20251a56.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/239_dd4166a1.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/240_b8a6619b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/241_4bb64d58.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/242_1c62ca06.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/243_b0b56429.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/244_2ccbf79d.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/245_be823269.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/246_e55a65f8.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/247_8148a341.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/248_bbcb6816.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/249_b2ecbae5.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/250_346f0e2a.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/251_e7bdc000.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/252_b08e48ca.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/253_613c6208.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/254_c5891c02.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/255_5b7c22ba.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/256_7f51e04f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/257_84b3bd8b.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/258_a0db5eb9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/259_925bb252.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/260_52e2ef9f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/261_7b55a188.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/262_75c671aa.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/263_5e05af36.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/264_fbd15802.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/265_41067f41.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/266_cd53e74c.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/267_39cef350.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/268_fdb12de1.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/269_255fa7f0.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/270_920e75b3.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/271_b38b6cde.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/272_8f9d6600.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/273_9e2e0136.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/274_be9abb72.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/275_e3011ffc.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/276_8ae3bad9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/277_8765bfc6.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/278_5dbe9461.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/279_7ee2412e.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/280_9c3237d1.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/281_75833814.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/282_9e123f75.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/283_2c906ba5.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/284_0a64e0f8.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/285_0cc0d5b7.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/286_67100a65.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/287_94d2d73f.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/288_c4b75830.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/289_2642c1f8.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/290_72382509.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/291_5cd0d9b9.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/292_3f8a0230.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/293_591f2212.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/294_5ad23946.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/295_79dff7e4.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/296_481c2e30.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/297_d61f5da0.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/298_981fa633.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/299_d7cd9377.jpg'),
#  Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses/300_dbb1fc9e.jpg')]

# %%
# path.ls() allows you to make sure that the differnt classes have been created,
# in this case it is five folders. Make sure all five are there and that there are
# no extra files.
path.ls()
# Out:
# (#6) [Path('/content/drive/MyDrive/unpack_ai/glasses_classification/face_with_glasses'),Path('/content/drive/MyDrive/unpack_ai/glasses_classification/face_without_glasses'),Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses_on_dummies'),Path('/content/drive/MyDrive/unpack_ai/glasses_classification/dummies_and_puppet'),Path('/content/drive/MyDrive/unpack_ai/glasses_classification/glasses'),Path('/content/drive/MyDrive/unpack_ai/glasses_classification/faces_without_glasses')]

# %% [markdown]
# ##### Displaying the image cleaner
#
# Use this to get rid of unsuitable images without leaving your notebook.

# %%
display_image_cleaner(path)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %% [markdown]
# Some time especially in real life projects, erronous image is a frequently occuring thing, you can fix the problem by deleting all of our faulty images.
#
# **We leave it up to you to finish your own model using your own dataset!**

# %%
clean_error_img(path)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]

# %% [markdown]
# ### Step Three - Data Transformation: Create your **DataLoaders** and utilize **Data Augmentation Methods** to improve your dataset.
#
# > Hint: Make sure to define your path so that it points to your main folder that contains your labeled folders with the images. A great way to do that is to use the *folder* icon on the left, to find the right folder, right click and *copy path*.

# %%
raptors = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2),
    get_y=parent_label,
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms()
)
dls = raptors.dataloaders(path)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
dls.valid.show_batch(max_n=10, nrows=2)

# %%
dls

# %%
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ### Step Three - Train your model.

# %%
#check that your GPU is active before training.
learn = cnn_learner(dls, resnet18, metrics=accuracy)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.044518</td>
#       <td>0.973812</td>
#       <td>0.643333</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.264000</td>
#       <td>0.824693</td>
#       <td>0.670000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.117793</td>
#       <td>0.737713</td>
#       <td>0.710000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.939574</td>
#       <td>0.679107</td>
#       <td>0.753333</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.833660</td>
#       <td>0.670190</td>
#       <td>0.753333</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Step Four - Interpret the model and make predictions: Create a notebook app to upload and classify external images.

# %% [markdown]
# > Hint: Utilize the *top losses* and *classification marix* methods seen in the coursebook to interpret your model.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#@title Getting a visual result for the top losses
def plot_top_losses_fix(interp, k, largest=True, **kwargs):
        losses,idx = interp.top_losses(k, largest)
        if not isinstance(interp.inputs, tuple): interp.inputs = (interp.inputs,)
        if isinstance(interp.inputs[0], Tensor): inps = tuple(o[idx] for o in interp.inputs)
        else: inps = interp.dl.create_batch(interp.dl.before_batch([tuple(o[i] for o in interp.inputs) for i in idx]))
        b = inps + tuple(o[idx] for o in (interp.targs if is_listy(interp.targs) else (interp.targs,)))
        x,y,its = interp.dl._pre_show_batch(b, max_n=k)
        b_out = inps + tuple(o[idx] for o in (interp.decoded if is_listy(interp.decoded) else (interp.decoded,)))
        x1,y1,outs = interp.dl._pre_show_batch(b_out, max_n=k)
        if its is not None:
            #plot_top_losses(x, y, its, outs.itemgot(slice(len(inps), None)), L(self.preds).itemgot(idx), losses,  **kwargs)
            plot_top_losses(x, y, its, outs.itemgot(slice(len(inps), None)), interp.preds[idx], losses,  **kwargs)
        #TODO: figure out if this is needed
        #its None means that a batch knows how to show itself as a whole, so we pass x, x1
        #else: show_results(x, x1, its, ctxs=ctxs, max_n=max_n, **kwargs)

plot_top_losses_fix(interp, 5, nrows=5)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('dummies_and_puppet', 'face_with_glasses', 'faces_without_glasses', 'glasses'…

# %%
#@title Delete or change classes of images as indicated in the `ImageClassifierCleaner`
#for idx in cleaner.delete(): cleaner.fns[idx].unlink() #Delete
#for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat) #Change Class

# %%
#@title If you delete or change the data set you must reload the data blocks and data loaders
#masks = DataBlock(
   #blocks=(ImageBlock, CategoryBlock), 
    #get_items=get_image_files, 
    #splitter=RandomSplitter(valid_pct=0.2),
    #get_y=parent_label,
    #item_tfms=RandomResizedCrop(224, min_scale=0.5),
    #batch_tfms=aug_transforms()
#)
#dls = masks.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=accuracy)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.101061</td>
#       <td>1.166400</td>
#       <td>0.583333</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.353191</td>
#       <td>0.924167</td>
#       <td>0.670000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.139596</td>
#       <td>0.794105</td>
#       <td>0.703333</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.954051</td>
#       <td>0.681649</td>
#       <td>0.753333</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.858652</td>
#       <td>0.664287</td>
#       <td>0.763333</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet18, metrics=accuracy)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.149438</td>
#       <td>1.149339</td>
#       <td>0.576667</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.299358</td>
#       <td>0.878285</td>
#       <td>0.653333</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.133127</td>
#       <td>0.827318</td>
#       <td>0.716667</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.988098</td>
#       <td>0.762653</td>
#       <td>0.730000</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.873211</td>
#       <td>0.744054</td>
#       <td>0.730000</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fine_tune??

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#@title Build the functionality of our Notebook App
uploader = widgets.FileUpload()
output = widgets.Output()
classify = widgets.Button(description='Classify')
prediction = widgets.Label()

def on_click_classify(change):
    img = PILImage.create(uploader.data[-1])
    output.clear_output()
    with output: 
      display(img.to_thumb(254,254))
    pred, pred_idx, probs = learn.predict(img)
    prediction.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

classify.on_click(on_click_classify)

VBox([widgets.Label('Select your image!'), 
      uploader, classify, output, prediction])
# Out:
# VBox(children=(Label(value='Select your image!'), FileUpload(value={}, description='Upload'), Button(descripti…
